# %% [markdown]
# ###  Importing necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###  Importing data

# %%
file_path = r'C:\Users\Hectic\space_mission_launches\starting_file\mission_launches.csv'

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Data cleaning and preparing for analysis

# %% [markdown]
# ### Dropping column Unnamed: 0.1

# %%
df.drop(columns='Unnamed: 0.1', inplace=True)

# %% [markdown]
# ### Viewing dataframe

# %%
df
# Out:
#       Unnamed: 0 Organisation  \
# 0              0       SpaceX
# 1              1         CASC
# 2              2       SpaceX
# 3              3    Roscosmos
# 4              4          ULA
# ...          ...          ...
# 4319        4319      US Navy
# 4320        4320         AMBA
# 4321        4321      US Navy
# 4322        4322    RVSN USSR
# 4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# ...

# %% [markdown]
# ### Renaming column Unnamed: 0 to index

# %%
df.rename(columns={'Unnamed: 0': 'index'}, inplace=True)

# %% [markdown]
# ### Viewing DataFrame

# %%
df
# Out:
#       index Organisation                                           Location  \
# 0         0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2         2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3         3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4         4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...     ...          ...                                                ...
# 4319   4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320   4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321   4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322   4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323   4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# ...

# %% [markdown]
# ### Specifying the value to replace NaN in the 'Price' column

# %%
replacement_value = 'No Info'

# %% [markdown]
# ### Replacing NaN with 'No Info' in the 'Price' column

# %%
df['Price'].fillna(replacement_value, inplace=True)

# %% [markdown]
# ### Viewing dataframe

# %%
df
# Out:
#       index Organisation                                           Location  \
# 0         0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2         2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3         3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4         4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...     ...          ...                                                ...
# 4319   4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320   4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321   4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322   4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323   4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# ...

# %% [markdown]
# ### Showing unique values in Rocket_Status column

# %%
print("Unique Rocket Statuses:", df['Rocket_Status'].unique())
# Out:
# Unique Rocket Statuses: ['StatusActive' 'StatusRetired']

# %% [markdown]
# ### Renaming values in Rocket_Status column

# %% [markdown]
# ### Defining the mapping for renaming values

# %%
status_mapping = {'StatusActive': 'Status: Active', 'StatusRetired': 'Status: Retired'}

# %% [markdown]
# ### Using the map function to replace values in the 'Rocket_Status' column

# %%
df['Rocket_Status'] = df['Rocket_Status'].map(status_mapping).fillna(df['Rocket_Status'])

# %% [markdown]
# ### Viewing DataFrame

# %%
df
# Out:
#       index Organisation                                           Location  \
# 0         0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2         2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3         3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4         4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...     ...          ...                                                ...
# 4319   4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320   4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321   4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322   4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323   4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# ...

# %% [markdown]
# ### Removing unnamed column

# %% [markdown]
# # Identifying and dropping the unnamed index column to avoid confusion

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.set_index('index', inplace=True)

# %% [markdown]
# ### Viewing dataframe

# %%
df
# Out:
#       Organisation                                           Location  \
# index
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2           SpaceX                      Pad A, Boca Chica, Texas, USA
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...            ...                                                ...
# 4319       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320          AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                              Date  \
# index
# 0      Fri Aug 07, 2020 05:12 UTC
# 1      Thu Aug 06, 2020 04:01 UTC
# ...

# %% [markdown]
# ### Converting date to datetime format

# %%
df['Date'] = pd.to_datetime(df['Date'], utc=True, errors='coerce')

# %% [markdown]
# ### Viewing DataFrame

# %%
df
# Out:
#       Organisation                                           Location  \
# index
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2           SpaceX                      Pad A, Boca Chica, Texas, USA
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...            ...                                                ...
# 4319       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320          AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Date                                        Detail  \
# index
# ...

# %% [markdown]
# ### Checking column format types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organisation    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   datetime64[ns, UTC]
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           4324 non-null   object
#  6   Mission_Status  4324 non-null   object
# dtypes: datetime64[ns, UTC](1), object(6)
# memory usage: 270.2+ KB

# %% [markdown]
# ### Removing timezone information from date column

# %%
df['Date'] = df['Date'].dt.tz_localize(None)

# %% [markdown]
# ### Viewing DataFrame

# %%
df
# Out:
#       Organisation                                           Location  \
# index
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2           SpaceX                      Pad A, Boca Chica, Texas, USA
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...            ...                                                ...
# 4319       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320          AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                      Date                                        Detail  \
# index
# ...

# %% [markdown]
# ### Correcting data types in dataframe

# %%
df[['Organisation', 'Location', 'Detail', 'Rocket_Status', 'Mission_Status']] = df[['Organisation', 'Location', 'Detail', 'Rocket_Status', 'Mission_Status']].astype(str)

# %% [markdown]
# ### Checking DataFrame data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organisation    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   datetime64[ns]
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           4324 non-null   object
#  6   Mission_Status  4324 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 270.2+ KB

# %% [markdown]
# ### Converting Price column to numeric

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %% [markdown]
# ### Checking DataFrame data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organisation    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   datetime64[ns]
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           949 non-null    float64
#  6   Mission_Status  4324 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 270.2+ KB

# %% [markdown]
# ### Checking if Price column contains , values

# %%
contains_comma = df[df['Price'].astype(str).str.contains(',', na=False)]

# Print the length of the resulting DataFrame
print(f"Number of rows with commas in the 'Price' column: {len(contains_comma)}")
# Out:
# Number of rows with commas in the 'Price' column: 0

# %% [markdown]
# ### Viewing DataFrame

# %%
df
# Out:
#       Organisation                                           Location  \
# index
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2           SpaceX                      Pad A, Boca Chica, Texas, USA
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...            ...                                                ...
# 4319       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320          AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                      Date                                        Detail  \
# index
# ...

# %% [markdown]
# ### Specifying the value to replace NaN in the 'Price' column

# %%
replacement_value = 'No Info'

# %% [markdown]
# ### Replacing NaN with 'No Info' in the 'Price' column

# %%
df['Price'].fillna(replacement_value, inplace=True)

# %% [markdown]
# ### Viewing DataFrame

# %%
df
# Out:
#       Organisation                                           Location  \
# index
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2           SpaceX                      Pad A, Boca Chica, Texas, USA
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...            ...                                                ...
# 4319       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320          AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321       US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                      Date                                        Detail  \
# index
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### DataFrame exporting

# %% [markdown]
# ### Exporting cleaned DataFrame

# %%
file_path = r'C:\Users\Hectic\space_mission_launches\cleaned_starting_file\mission_launches_df_cleaned.csv'


df.to_csv(file_path, index=False)
